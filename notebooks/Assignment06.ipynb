# %% [markdown]
# # Examples \& Exercises
#
# This assignment explores datasets from
#
# 1) [Copernicus Marine MyOcean Viewer](https://data.marine.copernicus.eu/viewer/expert?view=viewer&crs=epsg%3A4326&t=1755316800000&z=0&center=293.5449315539908%2C0&zoom=9.758224817722105&layers=H4sIABTQ.2gAA7WQ22rCQBCG32Wuo042WmzuotgYiFWa3kgpyza7OcAmG3IoWsm7dzUtxkKLFLyc4Z9._L6XA6g6EeVcqZJXYB9aAyTbi9LjYIPrr2eOT51Hx98GXvCwflrMneCZztw5RTQpkukozERW0UxxGktF3_JwUEQ1ZXkUUhySCRcx3ZirQUYJEss0R2EiwYAPL_diBzZBA9LjKypRr2UaJ7VbqqY4.e_yabXYFVKVaR6DXZeN0DkVByGTAuyIyUov3plsxCrNwdaF3cB0PQ5NA0KljzPWVdYiK9SpdJlyLvTBsbE1buAhb.7ykCur58E6ezCvRP7FVR.rwssQESfkvq_H4D.BN8vtF.j4B3iR7Ae6r2bqmx2n1gX8GO9GXaLHPz7zk6v429dPent8k7sCAAA-&basemap=dark), where you may choose which ocean product (usually modeling or reanalysis, which means model results incorporating with real ocean observations) to visulize by clicking "add layer" and then choose the ocean product. I have pulled out monthly averaged sea surface temperature and biogeochemical properties of the global oceans in August 2025 in the link above, but you should feel free to explore any dataset or different variables from the existing datasets.
#
# <img src="../figures/lecture07/copernicus_1.png" width="400">
#
# <img src="../figures/lecture07/copernicus_2.png" width="600">
#
# 2) [GO-BGC Argo](https://www.go-bgc.org/array-status#locations), which utilizes autonomous robotic floats to measure temperature, salinity, pH, nitrate, chlorophyll, suspended particles, light, and derived parameters DIC, pCO2 and total alkalinity in the ocean from the surface to 2000 m. These floats can operate continuously for years in all weather conditions, providing near real-time observations of ocean biogeochemistry and ecosystems throughout the world’s oceans. Watch [this Instagram Reel](https://www.instagram.com/reel/DLgi3pSoFth/) for a 1-minute introduction on how Argo floats work, including a video clip of their deployment!
#
# <img src="https://www3.mbari.org/gobgc/images/sensor_count_map.png" width="600">
#
# You can visualize observations from a single GO-BGC Argo float by clicking the Argo icon, and then clicking "Float status from Euro-Argo".
#
# <img src="../figures/lecture07/go-bgc_1.png" width="600">
#
# We will not code for this assignment so no examples will be provided. Assignments will be the  <font color="orange">Exercises</font>.
#
# # Your answers to the exercises:
# Please complete your exercises below:

# %% [markdown]
# ## Exercise 1
#
# The schematics below show seasonal variations of surface wind patterns.
#
# <img src="../figures/lecture07/wind_season.jpeg" width="700">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Exercise 1:</b> Based on the wind patterns during winter and summer shown in the schematics below, explain whether you would expect upwelling or downwelling off the coast of Peru. Is there a seasonal upwelling or downwelling system in this region? If so, during which season would you expect it to occur? (1 pt) Confirm your speculation by examining monthly averaged sea surface temperatures during austral summer and winter from <a href="https://data.marine.copernicus.eu/viewer/expert?view=viewer&crs=epsg%3A4326&t=1755316800000&z=0&center=293.5449315539908%2C0&zoom=9.758224817722105&layers=H4sIABTQ.2gAA7WQ22rCQBCG32Wuo042WmzuotgYiFWa3kgpyza7OcAmG3IoWsm7dzUtxkKLFLyc4Z9._L6XA6g6EeVcqZJXYB9aAyTbi9LjYIPrr2eOT51Hx98GXvCwflrMneCZztw5RTQpkukozERW0UxxGktF3_JwUEQ1ZXkUUhySCRcx3ZirQUYJEss0R2EiwYAPL_diBzZBA9LjKypRr2UaJ7VbqqY4.e_yabXYFVKVaR6DXZeN0DkVByGTAuyIyUov3plsxCrNwdaF3cB0PQ5NA0KljzPWVdYiK9SpdJlyLvTBsbE1buAhb.7ykCur58E6ezCvRP7FVR.rwssQESfkvq_H4D.BN8vtF.j4B3iR7Ae6r2bqmx2n1gX8GO9GXaLHPz7zk6v429dPent8k7sCAAA-&basemap=dark">Copernicus Marine MyOcean Viewer</a>. (1 pt)
# </div>

# %% [markdown]
# ## Exercise 2
#
# <div class="alert alert-block alert-warning">
# <b>Exercise 2:</b> In the <a href="https://data.marine.copernicus.eu/viewer/expert?view=viewer&crs=epsg%3A4326&t=1755316800000&z=0&center=293.5449315539908%2C0&zoom=9.758224817722105&layers=H4sIABTQ.2gAA7WQ22rCQBCG32Wuo042WmzuotgYiFWa3kgpyza7OcAmG3IoWsm7dzUtxkKLFLyc4Z9._L6XA6g6EeVcqZJXYB9aAyTbi9LjYIPrr2eOT51Hx98GXvCwflrMneCZztw5RTQpkukozERW0UxxGktF3_JwUEQ1ZXkUUhySCRcx3ZirQUYJEss0R2EiwYAPL_diBzZBA9LjKypRr2UaJ7VbqqY4.e_yabXYFVKVaR6DXZeN0DkVByGTAuyIyUov3plsxCrNwdaF3cB0PQ5NA0KljzPWVdYiK9SpdJlyLvTBsbE1buAhb.7ykCur58E6ezCvRP7FVR.rwssQESfkvq_H4D.BN8vtF.j4B3iR7Ae6r2bqmx2n1gX8GO9GXaLHPz7zk6v429dPent8k7sCAAA-&basemap=dark">Copernicus Marine MyOcean Viewer</a>, hide the sea surface temperature layer and turn on the sea surface nitrate concentration and chlorophyll layers, respectively. What patterns do you observe off the coast of Peru during austral winter (August 2025)? Can you explain these patterns by connecting them to coastal upwelling and downwelling dynamics? Please discuss both the physical and biogeochemical processes. (1 pt) Tip: Lecture 07, Section 2.3: The Ecology of Coastal Upwelling Systems? Visualize and take a screenshot of any variables from Carbon monthly, CO₂ monthly, Primary Production and O₂ monthly, Zooplankton Carbon Biomass monthly, and explain their patterns off the coast of Peru. Then, explain how coastal upwelling systems can sequester carbon through the
# <a href="https://theoceanexplained.wordpress.com/2021/07/13/the-three-carbon-pumps-of-the-ocean-biological-carbonate-and-physical/">physical or biological carbon pump</a>. (1 pt)
# </div>

# %% [markdown]
# ## Exercise 3
#
# <div class="alert alert-block alert-warning">
# <b>Exercise 3:</b> GO-BGC Argos <a href="https://fleetmonitoring.euro-argo.eu/float/3902556">3902556</a> and <a href="https://fleetmonitoring.euro-argo.eu/float/5906573">5906573</a> have been deployed at similar latitudes (13°S and 14°S, respectively), but more than 2,500 km apart in longitude. They have been drifting with the flow while sampling the ocean column for the past 2–3 years. When you click into the website, you should see the drifting trajectories on the right side of the webpage and many summary plots of various observational variables on the left side. Compare the overlaid CHLA (chlorophyll-a concentration from all the profiles) sampled by the two Argo floats. Which station has more primary productivity? Explain why. (1 pt) Tip: you may compare the overlaid NITRATE (nitrate concentration) profiles and approach from the angle of nutrient availability associated with coastal upwelling/downwelling systems.
# </div>

# %% [markdown]
# ## Additional Exercise
#
# <div class="alert alert-block alert-warning">
# <b>Additional Exercise: </b> Coastal upwelling is particularly profound in eastern boundary upwelling systems, such as the California Current System (CCS), the Canary Current System, the Humboldt Current System, and the Benguela Current System, which are among the most productive ecosystems in the global ocean. Can you identify all four upwelling systems using any Copernicus Marine MyOcean Viewer visualizations? Take a screenshot of the visualization of your choice and mark the four upwelling systems. (1 pt)
# </div>
