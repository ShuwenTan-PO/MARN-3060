# %% [markdown]
# # Examples \& Exercises
#
# This assignment examines data collected during two field trips: our 10/31 visit to the Avery Point dock, and another group's 11/3 trip, which covered the route from <font color="red">Norwich Harbor to the Montville Power Plant and the Coast Guard Academy</font>. The respective datasets are provided in the files titled "UCONN 3060 data 10_31_2025.pdf" and "MSMHS 11-3-25.pdf." <font color="forestgreen">Note that the datasheets are color-coded. For example, blue represents the Navigation Data Sheet, which includes readings taken in the navigation room. Orange, green, and pink contains nutrient concentration we measured in the Enviro-Lab.</font>.
#
# Also during our October 31st field trip, we analyzed nutrient concentrations and turbidity levels from surface water samples collected at five distinct locations. Below are the GPS coordinates for each sampling site, along with the corresponding water temperatures recorded at the time of collection.
#
# - A- Sprague River Park, Baltic   41.618641° N, -72.085395° W  Surface temp 10.5 °C
# - B- Howard T. Brown Memorial Park, Norwich   41.522613° N, -72.078420° W,  Surface temp 11.5° C
# - C- Stoddard Hill State boat launch , Ledyard   41.460127° N, -72.067618° W Surface temp 13° C
# - D- Kenneth Streeter State Boat ramp, Groton  41.363945° N, -72.084838° W Surface temp  14° C
# - E- Avery Point Dock, Groton  41.316867° N, -72.0608167° W  Surface temp 14.7° C
#
# We will not code for this assignment so no examples will be provided. Assignments will be the  <font color="orange">Exercises</font>.
#
# # Your answers to the exercises:
# Please complete your exercises below:

# %% [markdown]
# ## Exercise 1
#
# <div class="alert alert-block alert-warning">
# <b>Exercise 1:</b>
#
# - During what tidal phase (flood vs. ebb) did the stations from the two trips occur? You will need to list the tidal phase for all three stations during the 11/3 trip and one station during the 10/31 trip (tip: find this information in the Navigation Data Sheet). (0.2 pt)
# - Discuss the expected direction and relative intensity of seawater intrusion versus river discharge during flood and ebb tides. (0.3 pt)
# - Discuss how you expect the surface salinity to differ among the three stations sampled on 11/3. Explain why, and whether or not you would expect the same amount of salinity change during flood tide. Refer to the salinity measurements from the three stations sampled on 11/3, and discuss whether the observations confirm your expectations. (0.5 pt)
# - How does the bottom salinity measured at Norwich Harbor on 11/3 compare to that at Avery Point Dock on 10/31? How do you expect salinity from surface to bottom to vary during ebb tide versus flood tide? Refer to the salinity measurements from the three stations sampled on 11/3, and discuss whether the observations confirm your expectations. (Tip: see how tidal phases influence the movement and mixing of water in the estuary in the figure in Lecture 06, section 3.1) (0.5 pt)
#
# </div>

# %% [markdown]
# ## Exercise 2
#
# <div class="alert alert-block alert-warning">
# <b>Exercise 2:</b>
#
# - Calculate the mean nutrient concentrations (ammonium, phosphate, nitrate) from the surface water samples collected at five stations (A–F; see GPS coordinates in the Examples & Exercises) along the Thames River on 10/31. Compare the magnitudes among the five stations, identify which station had the highest surface nutrient levels for each nutrient, and determine whether all three nutrients had their highest concentrations at the same station. Explore possible reasons for these patterns. (1 pt)
# - Repeat the same analysis for both surface and bottom water samples collected from three stations (Norwich Harbor, Montville Power Plant, Coast Guard Academy) along the Thames River on 11/3. (1 pt) Identify the station with the highest nutrient concentration. In addition, compare nutrient concentrations between surface and bottom samples, and explain the observed differences. (0.5 pt)
# </div>

# %% [markdown]
# ## Exercise 3
#
# <div class="alert alert-block alert-warning">
# <b>Exercise 3:</b>
#
# Hypoxia is defined as low levels of dissolved oxygen (typically less than 2–3 milligrams of oxygen per liter of water). Review the dissolved oxygen data measured by the TSI meter at the three stations (Norwich Harbor, Montville Power Plant, Coast Guard Academy) sampled on 11/3, and identify the relationship between dissolved oxygen and depth. Identify any regions where hypoxia is present. Does hypoxia occur at different stations at the same depth? Explain possible reasons for this observation. (1 pt)
#
# - Tip 1: Surface winds are stronger near the mouth while the upper estuary is characterized by lighter winds at river level due to sheltering from the hills that surround the area and distance from open water. Consequently, winddriven mixing is most likely less energetic in the upper estuary. - <a href="https://digitalcommons.lib.uconn.edu/cgi/viewcontent.cgi?article=1262&context=gs_theses">Hacker Gibson, Melissa, "Physical Processes that Affect Hypoxia in the Thames River Estuary, USA" (2012). Master's Theses. 228. https://digitalcommons.lib.uconn.edu/gs_theses/228</a>
# - Tip 2: Strong mixing can blend surface low-salinity, oxygen-rich water with deeper layers, reducing the difference in salinity and oxygen between surface and bottom waters.
#
# </div>

# %% [markdown]
# ## Additional Exercise
#
# <div class="alert alert-block alert-warning">
# <b>Additional Exercise: </b>
#
# Can you identify any measurements in the datasheet that seem suspicious or unexpected? Explain possible reasons, they could be instrument misreadings, instrumentation errors, water sample contamination, or results that are valid but differ from expectations. (1 pt)
#
# For example, temperature measurements at the Norwich Harbor station suggest an increase in temperature with depth, which was unexpected to me. I initially wondered whether colder water above warmer water might cause instability (thinking about boiling water on stove). However, this pattern makes sense considering that the air temperature was colder than the river water, leading to surface cooling. Additionally, salinity increases with depth that cuases density also increases with depth, which prevent the water from being unstable.
#
# </div>
